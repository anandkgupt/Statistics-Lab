# %% [markdown]
# <a href="https://colab.research.google.com/github/anandkgupt/Statistics-Lab/blob/main/Statistics_Advance_Part_1_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Statistics Advance Part-1**

# %% [markdown]
# Q1. What is a random variable in probability theory?
#
# ANS: In probability theory, a random variable is a numerical quantity whose value depends on the outcome of a random experiment. It serves as a bridge between outcomes of a sample space and real numbers, allowing mathematical analysis.

# %% [markdown]
# Q2. What are the types of random variables?
#
# ANS: Random variables are classified into two main types based on the nature of the values they can take:
#
# 1. Discrete Random Variables
# A discrete random variable takes on a countable number of distinct values, often integers.
#
# 2. Continuous Random Variables
# A continuous random variable takes on an uncountable, infinite set of values within a range or interval.

# %% [markdown]
# Q3. What is the difference between discrete and continuous distributions?
#
# ANS: The key difference between discrete and continuous distributions lies in the nature of the random variables they describe and how probabilities are assigned to outcomes.
#
# 1. Discrete Distributions
# A discrete distribution describes the probabilities of a discrete random variable, which can take on a finite or countably infinite set of distinct values.
#
# Characteristics:
#
# Values: Specific, countable values (e.g., integers).
#
# Probability Assignment: Probabilities are assigned to each individual value of the random variable.
#
# 2. Continuous Distributions
# A continuous distribution describes the probabilities of a continuous random variable, which can take on any value within a range or interval.
#
# Characteristics:
#
# Values: Any value within a continuous range (e.g., real numbers).

# %% [markdown]
# Q4. What are probability distribution functions (PDF)?
#
# ANS: In probability theory, a Probability Distribution Function (PDF) describes how probabilities are distributed over the values of a random variable. The term PDF is used differently for discrete and continuous random variables.

# %% [markdown]
# Q5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# ANS: The Cumulative Distribution Function (CDF) and the Probability Distribution Function (PDF) differ in their definitions, roles, and applications in describing probability distributions.
#
# **PDF (Probability Distribution Function)**
# Represents the probability distribution of a random variable.
# For discrete random variables, it is called the Probability Mass Function (PMF), and for continuous random variables, it is the Probability Density Function (PDF).
#
# **CDF (Cumulative Distribution Function)**
# Represents the cumulative probability up to a certain value of the random variable.
# It provides the probability that a random variable
#
# X takes on a value less than or equal to
# 𝑥 .

# %% [markdown]
# Q6.  What is a discrete uniform distribution?
#
# ANS: A discrete uniform distribution is a type of probability distribution in which a discrete random variable
# X has an equal probability of taking any value from a finite set of
# n values.
#
# A discrete uniform distribution is used when all outcomes are equally likely and finite, making it a straightforward and widely applicable probability model.

# %% [markdown]
# Q7. What are the key properties of a Bernoulli distribution?
#
# ANS: The Bernoulli distribution is a discrete probability distribution that models a random experiment with exactly two possible outcomes: success (1) and failure (0). It is the simplest form of a probability distribution and has several key properties:
#
# **Key Properties of a Bernoulli Distribution:**
#
# Parameters:
# 𝑝
# p: Probability of success (
# 0
# ≤
# 𝑝
# ≤
# 1
# 0≤p≤1).
#
# Expected Value (Mean):
# The expected value represents the average outcome of the experiment.
#
# Variance:
# The variance measures the spread of the outcomes.
#
# Cumulative Distribution Function (CDF)
#
# Support:
# The random variable
# X takes only two possible values:
# 0 and
# 1.
#
# Independence:
# If multiple Bernoulli trials are performed, the outcomes are often assumed to be independent unless specified otherwise.

# %% [markdown]
# Q8. What is the binomial distribution, and how is it used in probability?
#
# ANS: The binomial distribution is a discrete probability distribution that models the number of successful outcomes in a fixed number of independent trials, each with two possible outcomes (usually referred to as "success" and "failure"). The binomial distribution is applicable when:
#
# Fixed number of trials (n): The experiment is repeated a specific number of times.
#
# Two outcomes per trial: Each trial results in either a success or failure.
#
# Constant probability of success (p): The probability of success remains the same for each trial.
#
# Independence: The outcome of one trial does not affect the outcome of another trial.

# %% [markdown]
# Q9. What is the Poisson distribution and where is it applied?
#
# ANS: The Poisson distribution is a discrete probability distribution used to model the number of times an event occurs in a fixed interval of time, space, or other domains, under the assumption that the events happen independently and at a constant average rate.
#
# **When to Use the Poisson Distribution:**
#
# When events occur independently.
#
# When events occur at a constant average rate.
#
# When the number of events in any given interval is proportional to the length of the interval.

# %% [markdown]
# Q10. What is a continuous uniform distribution?
#
# ANS: The continuous uniform distribution is a probability distribution in which all outcomes within a given interval are equally likely. It is the simplest form of a continuous probability distribution and is used to model situations where there is no preference for any particular outcome within the range.

# %% [markdown]
# Q11. What are the characteristics of a normal distribution?
#
# ANS: **Characteristics of a Normal Distribution:**
#
# **1. Shape: Bell-shaped Curve:**
#
# The graph of a normal distribution is a symmetric, bell-shaped curve centered around the mean.
#
# The highest point occurs at the mean, and the curve tapers off symmetrically on both sides.
#
# **2. Symmetry:**
#
# It is perfectly symmetric about the mean (μ).
#
# The left side of the curve is a mirror image of the right side.
#
# **3. Mean, Median, and Mode:**
#
# The mean, median, and mode are all equal and located at the center of the distribution.
#
# This reflects the balance of the distribution.

# %% [markdown]
# Q12. What is the standard normal distribution, and why is it important?
#
# ANS: The standard normal distribution is a special case of the normal distribution that has a mean (
# 𝜇
# μ) of 0 and a standard deviation (
# σ) of 1. It is denoted as
# Z∼N(0,1), where
# Z represents a random variable following this distribution.
#
# **Importance of the Standard Normal Distribution:**
#
# Simplifies Calculations: Converting data to the standard normal distribution (via z-scores) allows for easy calculation of probabilities and comparison of values across different datasets.
#
# Universal Reference: The standard normal distribution serves as a reference model for all normal distributions, making it possible to use standardized tables (z-tables) for probability and percentile calculations.
#
# Facilitates Comparisons: By standardizing data, it becomes easier to compare values from distributions with different means and standard deviations.

# %% [markdown]
# Q13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# ANS: The Central Limit Theorem (CLT) is a fundamental concept in statistics that describes the behavior of the sampling distribution of the sample mean (or sum) as the sample size increases. It is critical because it allows statisticians to make inferences about population parameters using sample data, even when the population distribution is not normal.

# %% [markdown]
# Q14.  How does the Central Limit Theorem relate to the normal distribution?
#
# ANS: The Central Limit Theorem (CLT) relates to the normal distribution by explaining how the sampling distribution of the sample mean (or sum) approaches a normal distribution as the sample size increases, regardless of the shape of the original population distribution.

# %% [markdown]
# Q15. What is the application of Z statistics in hypothesis testing?
#
# ANS: Application of Z-Statistics in Hypothesis Testing
# Z-statistics are widely used in hypothesis testing to determine whether there is enough evidence to reject a null hypothesis (
# 𝐻
# 0) in favor of an alternative hypothesis (
# 𝐻
# 𝑎). This method is applicable when the data is normally distributed or when the Central Limit Theorem (CLT) allows us to approximate the sampling distribution as normal.

# %% [markdown]
# Q16. How do you calculate a Z-score, and what does it represent?
#
# ANS: **Z-Score:** A Z-score (or standard score) measures how many standard deviations a data point is from the mean of its distribution. It provides a way to standardize data, enabling comparisons across different datasets or distributions.
#
# **Formula to Calculate a Z-Score:**
# For an individual data point (X):
#
# 𝑍=𝑋−𝜇/𝜎
#
# Where:
#
# X: The data point being analyzed.
#
# μ: The mean of the dataset or population.
#
# σ: The standard deviation of the dataset or population.
#
# **Z-Score Represent:** Position Relative to the Mean, Standardized Value & Probability.

# %% [markdown]
# Q17. What are point estimates and interval estimates in statistics?
#
# ANS: **Point Estimate:**
# A point estimate is a single value that serves as an estimate of an unknown population parameter. It is calculated from sample data and provides the best guess or approximation of the parameter based on the sample.
#
# **Interval Estimate:**
# An interval estimate provides a range of values within which the population parameter is likely to fall. It includes a margin of error around the point estimate, reflecting the uncertainty due to sampling variability.

# %% [markdown]
# Q18. What is the significance of confidence intervals in statistical analysis?
#
# ANS: **Significance of Confidence Intervals in Statistical Analysis:**
# A confidence interval (CI) is a range of values used to estimate an unknown population parameter, with an associated level of confidence. It provides more information than a single point estimate by acknowledging the uncertainty inherent in sampling and allowing for inferences about a population based on sample data.

# %% [markdown]
# Q19. What is the relationship between a Z-score and a confidence interval?
#
# ANS: **Relationship Between Z-Score and Confidence Interval:**
# A Z-score and a confidence interval (CI) are closely related concepts in statistics, particularly when estimating population parameters based on sample data. The Z-score is used in the calculation of confidence intervals, and it plays a key role in determining how wide or narrow the confidence interval will be.

# %% [markdown]
# Q20.  How are Z-scores used to compare different distributions?
#
# ANS: **Using Z-Scores to Compare Different Distributions:**
# Z-scores are a powerful tool for comparing data points or distributions, even when the data come from different populations with different means and standard deviations. They allow you to standardize the values, making it possible to compare them on the same scale.

# %% [markdown]
# Q21. What are the assumptions for applying the Central Limit Theorem?
#
# ANS: The Central Limit Theorem (CLT) is a powerful statistical concept that helps us understand the distribution of sample means, but its applicability depends on several key assumptions. Here are the key assumptions for applying the CLT:
#
# **Random Sampling:** Samples should be chosen randomly.
#
# **Independence:** Observations must be independent of each other.
#
# **Sample Size:** A sufficiently large sample size (typically
# n≥30), or smaller if the population is normal.
#
# **Finite Variance:** The population should have finite variance.
#
# **No Extreme Skewness for Small Samples:** Avoid significant skewness or outliers in small samples.

# %% [markdown]
# Q22. What is the concept of expected value in a probability distribution?
#
# ANS: **Concept of Expected Value in a Probability Distribution:**
#
# The expected value (also known as the mean or mathematical expectation) is a key concept in probability theory and statistics. It represents the average or long-term mean of a random variable, weighted by the probabilities of the possible outcomes.
#
# In simple terms, the expected value is the theoretical average of a random variable over many trials or occurrences. It helps in understanding what the "central" value of a random variable would be, if the random process were repeated infinitely.

# %% [markdown]
# Q23. How does a probability distribution relate to the expected outcome of a random variable?
#
# ANS: A probability distribution describes how the probabilities of a random variable are distributed over its possible values. It is the foundation for calculating various statistical measures, including the expected value (mean) of the random variable, which represents the expected outcome or long-term average of that variable.
#
# The probability distribution provides the necessary information about the likelihood of each possible outcome of a random variable. The expected value is derived from this distribution and represents the average or mean outcome that one would expect if the process were repeated many times. Thus, the expected value is closely tied to the probability distribution, as it is a weighted average of the possible outcomes, with the weights being the probabilities of those outcomes.

# %% [markdown]
# # **Practical**

# %% [markdown]
# Q1. Write a Python program to generate a random variable and display its value.

# %%
import random

# Generate a random floating-point number between 0 and 1
random_number = random.random()

# Display the generated value
print("Random number:", random_number)
# Out:
# Random number: 0.18563701065284244

# %% [markdown]
# Q2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the parameters of the discrete uniform distribution
low = 1  # Lower bound (inclusive)
high = 6  # Upper bound (inclusive)

# Create a discrete uniform distribution object
dist = randint(low, high)

# Generate values for the x-axis (possible outcomes)
x = np.arange(low, high + 1)

# Calculate the PMF (probability mass function)
pmf = dist.pmf(x)

# Plot the PMF
plt.stem(x, pmf)
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title(f'PMF of Discrete Uniform Distribution ({low}, {high})')
plt.grid(True)
plt.show()

# %% [markdown]
# Q3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
import numpy as np

def bernoulli_pdf(x, p):
  """
  Calculates the probability density function (PDF) of a Bernoulli distribution.

  Args:
    x: The value of the random variable (0 or 1).
    p: The probability of success (probability of x=1).

  Returns:
    The probability density function value.
  """

  if x not in [0, 1]:
    raise ValueError("x must be either 0 or 1")

  if not (0 <= p <= 1):
    raise ValueError("p must be between 0 and 1")

  if x == 1:
    return p
  else:
    return 1 - p

# Example usage:
p = 0.7  # Probability of success
x = 1     # Value of the random variable

pdf_value = bernoulli_pdf(x, p)
print(f"PDF of Bernoulli({p}) at x={x}: {pdf_value}")
# Out:
# PDF of Bernoulli(0.7) at x=1: 0.7

# %% [markdown]
# Q4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success

# Generate random samples from the binomial distribution
data = binom.rvs(n=n, p=p, size=10000)  # Generate 10,000 samples

# Create the histogram
plt.hist(data, bins=range(n+1), density=True, align='left', rwidth=0.8)

# Calculate and plot the theoretical PMF
x = range(n+1)
pmf = binom.pmf(x, n, p)
plt.plot(x, pmf, 'ro', label='Theoretical PMF')

# Add labels and title
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Q5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the average rate of occurrence (lambda)
mu = 5

# Generate a range of possible values for the random variable
x = np.arange(0, 20)  # Adjust the upper limit as needed

# Calculate the probability mass function (PMF)
pmf = poisson.pmf(x, mu)

# Plot the PMF
plt.figure(figsize=(8, 5))
plt.bar(x, pmf, align='center', alpha=0.8)
plt.xlabel('Number of Occurrences')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ={mu})')
plt.xticks(x)  # Show all x-axis values
plt.grid(True)
plt.show()

# %% [markdown]
# Q6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define parameters of the discrete uniform distribution
low = 1  # Lower bound (inclusive)
high = 6  # Upper bound (inclusive)

# Create a discrete uniform distribution object
dist = uniform(loc=low, scale=high - low + 1)

# Generate values for the x-axis (possible outcomes)
x = np.arange(low, high + 1)

# Calculate the CDF (Cumulative Distribution Function)
cdf = dist.cdf(x)

# Plot the CDF
plt.step(x, cdf)
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title(f'CDF of Discrete Uniform Distribution ({low}, {high})')
plt.grid(True)
plt.show()

# %% [markdown]
# Q7.  Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters of the uniform distribution
low = 0  # Lower bound
high = 1  # Upper bound

# Generate random samples from the uniform distribution
data = np.random.uniform(low, high, size=10000)

# Create a histogram of the generated data
plt.hist(data, bins=50, density=True, alpha=0.7)

# Plot the probability density function (PDF) of the uniform distribution
x = np.linspace(low, high, 100)
pdf = 1 / (high - low) * np.ones_like(x)
plt.plot(x, pdf, 'r-', label='PDF')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Continuous Uniform Distribution')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Q8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters of the normal distribution
mu = 0  # Mean
sigma = 1  # Standard deviation

# Generate random samples from the normal distribution
data = np.random.normal(mu, sigma, 10000)

# Create the histogram
plt.hist(data, bins=50, density=True, alpha=0.6, color='g')

# Plot the probability density function (PDF) of the normal distribution
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='PDF')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Histogram of Normal Distribution')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Q9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
  """
  Calculates Z-scores for a given dataset.

  Args:
    data: A NumPy array or list containing the data.

  Returns:
    A NumPy array of Z-scores.
  """
  mean = np.mean(data)
  std_dev = np.std(data)
  z_scores = (data - mean) / std_dev
  return z_scores

# Example usage
data = np.array([10, 12, 8, 15, 11, 9, 13])
z_scores = calculate_z_scores(data)

# Plot the Z-scores
plt.figure(figsize=(8, 4))
plt.bar(range(len(data)), z_scores, color='skyblue')
plt.xlabel('Data Points')
plt.ylabel('Z-Score')
plt.title('Z-Scores of the Dataset')
plt.grid(True)
plt.show()

# %% [markdown]
# Q10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

# Parameters
num_samples = 10000
sample_size = 30

# Generate data from an exponential distribution (non-normal)
data = expon.rvs(size=num_samples * sample_size)

# Reshape data into samples
data = data.reshape(num_samples, sample_size)

# Calculate sample means
sample_means = np.mean(data, axis=1)

# Plot histogram of sample means
plt.hist(sample_means, bins=50, density=True, alpha=0.7, color='blue')
plt.xlabel('Sample Means')
plt.ylabel('Probability Density')
plt.title(f'Distribution of Sample Means (Sample Size: {sample_size})')

# Overlay a normal distribution for comparison
mu = np.mean(sample_means)
sigma = np.std(sample_means)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (x - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='red', label='Normal Distribution')

plt.legend()
plt.show()

# %% [markdown]
# Q15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_mean = 50
population_std_dev = 10
num_samples = 1000
sample_size = 30

# Generate sample means
sample_means = []
for _ in range(num_samples):
    sample = np.random.normal(population_mean, population_std_dev, sample_size)
    sample_means.append(np.mean(sample))

# Plot histogram of sample means
plt.hist(sample_means, bins=50, density=True, alpha=0.7, color='blue')
plt.xlabel('Sample Means')
plt.ylabel('Probability Density')
plt.title(f'Distribution of Sample Means (Sample Size: {sample_size})')

# Overlay a normal distribution for comparison
mean_of_means = np.mean(sample_means)
std_dev_of_means = np.std(sample_means)
x = np.linspace(mean_of_means - 3*std_dev_of_means, mean_of_means + 3*std_dev_of_means, 100)
plt.plot(x, 1/(std_dev_of_means * np.sqrt(2 * np.pi)) * np.exp( - (x - mean_of_means)**2 / (2 * std_dev_of_means**2) ),
         linewidth=2, color='red', label='Normal Distribution')

plt.legend()
plt.show()

# %% [markdown]
# Q16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
  """
  Calculates and plots the standard normal distribution (mean=0, std=1).

  Args:
    None

  Returns:
    None
  """
  # Define the range of x-values
  x = np.linspace(-3, 3, 100)

  # Calculate the probability density function (PDF)
  mean = 0
  std_dev = 1
  pdf = norm.pdf(x, mean, std_dev)

  # Plot the PDF
  plt.figure(figsize=(8, 5))
  plt.plot(x, pdf, color='blue')
  plt.xlabel('Z-score')
  plt.ylabel('Probability Density')
  plt.title('Standard Normal Distribution')
  plt.grid(True)
  plt.show()

# Call the function to plot the distribution
plot_standard_normal_distribution()

# %% [markdown]
# Q17. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom

# Define the parameters
n = 10  # Number of trials
p = 0.3  # Probability of success in each trial

# Generate random variables (number of successes)
random_variables = np.random.binomial(n, p, size=1000)

# Calculate probabilities for each random variable
probabilities = binom.pmf(random_variables, n, p)

# Print the results
for i in range(len(random_variables)):
    print(f"Random Variable: {random_variables[i]}, Probability: {probabilities[i]:.4f}")
# Out:
# Random Variable: 2, Probability: 0.2335
# Random Variable: 4, Probability: 0.2001
# Random Variable: 0, Probability: 0.0282
# Random Variable: 2, Probability: 0.2335
# Random Variable: 1, Probability: 0.1211
# Random Variable: 4, Probability: 0.2001
# Random Variable: 4, Probability: 0.2001
# Random Variable: 4, Probability: 0.2001
# Random Variable: 0, Probability: 0.0282
# Random Variable: 2, Probability: 0.2335
# Random Variable: 0, Probability: 0.0282
# Random Variable: 1, Probability: 0.1211
# Random Variable: 2, Probability: 0.2335
# Random Variable: 5, Probability: 0.1029
# Random Variable: 3, Probability: 0.2668
# Random Variable: 7, Probability: 0.0090
# Random Variable: 4, Probability: 0.2001
# Random Variable: 2, Probability: 0.2335
# Random Variable: 7, Probability: 0.0090
# Random Variable: 3, Probability: 0.2668
# Random Variable: 2, Probability: 0.2335
# Random Variable: 2, Probability: 0.2335
# Random Variable: 3, Probability: 0.2668
# ...

# %% [markdown]
# Q18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_and_plot_z_score(data_point, mean, std_dev):
  """
  Calculates the Z-score for a given data point and plots it on a standard normal distribution.

  Args:
    data_point: The data point for which to calculate the Z-score.
    mean: The mean of the population.
    std_dev: The standard deviation of the population.
  """

  # Calculate the Z-score
  z_score = (data_point - mean) / std_dev

  # Generate x-values for plotting the standard normal distribution
  x = np.linspace(-3, 3, 100)
  pdf = norm.pdf(x, 0, 1)

  # Plot the standard normal distribution
  plt.figure(figsize=(8, 5))
  plt.plot(x, pdf, color='blue', label='Standard Normal Distribution')

  # Plot a vertical line at the Z-score
  plt.axvline(z_score, color='red', linestyle='--', label=f'Z-score: {z_score:.2f}')

  # Add labels and title
  plt.xlabel('Z-score')
  plt.ylabel('Probability Density')
  plt.title('Standard Normal Distribution with Z-score')
  plt.legend()
  plt.grid(True)
  plt.show()

# Example usage
data_point = 75
mean = 70
std_dev = 5

calculate_and_plot_z_score(data_point, mean, std_dev)

# %% [markdown]
# Q19. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_mean, population_mean, population_std_dev, sample_size, alpha=0.05):
  """
  Performs a one-sample Z-test.

  Args:
    sample_mean: The mean of the sample.
    population_mean: The hypothesized population mean.
    population_std_dev: The population standard deviation.
    sample_size: The size of the sample.
    alpha: Significance level (default: 0.05).

  Returns:
    A tuple containing:
      - z_score: The calculated Z-score.
      - p_value: The p-value of the test.
      - reject_null: True if the null hypothesis is rejected, False otherwise.
  """

  # Calculate the Z-score
  z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

  # Calculate the p-value
  p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

  # Determine if the null hypothesis is rejected
  reject_null = p_value < alpha

  return z_score, p_value, reject_null

# Example usage
sample_mean = 102  # Sample mean
population_mean = 100  # Hypothesized population mean
population_std_dev = 15  # Population standard deviation
sample_size = 50

z_score, p_value, reject_null = z_test(sample_mean, population_mean, population_std_dev, sample_size)

print(f"Z-score: {z_score:.2f}")
print(f"p-value: {p_value:.4f}")

if reject_null:
  print("Reject the null hypothesis.")
else:
  print("Fail to reject the null hypothesis.")
# Out:
# Z-score: 0.94
# p-value: 0.3458
# Fail to reject the null hypothesis.

# %% [markdown]
# Q20. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
import scipy.stats as stats

# Generate a sample dataset (e.g., random data for demonstration)
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=100)  # Mean=50, Std Dev=10, Sample Size=100

# Calculate the sample mean and standard error
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # Use ddof=1 for sample standard deviation
sample_size = len(data)
standard_error = sample_std / np.sqrt(sample_size)

# Confidence level (e.g., 95%)
confidence_level = 0.95
z_critical = stats.norm.ppf((1 + confidence_level) / 2)  # Z-score for 95% confidence

# Calculate the margin of error and confidence interval
margin_of_error = z_critical * standard_error
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

# Output the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Standard Error: {standard_error:.2f}")
print(f"Z-critical value: {z_critical:.2f}")
print(f"Margin of Error: {margin_of_error:.2f}")
print(f"95% Confidence Interval: {confidence_interval}")
# Out:
# Sample Mean: 48.96
# Standard Error: 0.91
# Z-critical value: 1.96
# Margin of Error: 1.78
# 95% Confidence Interval: (47.18155741526743, 50.74151223685072)

# %% [markdown]
# Q21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy import stats

# Generate random data from a normal distribution
mu = 50  # Population mean
sigma = 10  # Population standard deviation
sample_size = 30
data = np.random.normal(loc=mu, scale=sigma, size=sample_size)

# Calculate sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # Sample standard deviation

# Confidence level
confidence_level = 0.95

# Calculate degrees of freedom
degrees_of_freedom = sample_size - 1

# Calculate t-critical value
t_critical = stats.t.ppf((1 + confidence_level) / 2, df=degrees_of_freedom)

# Calculate margin of error
margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))

# Calculate confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Standard Deviation: {sample_std:.2f}")
print(f"Confidence Level: {confidence_level * 100}%")
print(f"Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# Interpretation
print("\nInterpretation:")
print(f"We are {confidence_level * 100}% confident that the true population mean falls within the interval "
      f"({lower_bound:.2f}, {upper_bound:.2f}).")
# Out:
# Sample Mean: 50.53
# Sample Standard Deviation: 10.49
# Confidence Level: 95.0%
# Confidence Interval: (46.61, 54.45)
#
# Interpretation:
# We are 95.0% confident that the true population mean falls within the interval (46.61, 54.45).

# %% [markdown]
# Q22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the parameters of the normal distribution
mu = 0  # Mean
sigma = 1  # Standard deviation

# Generate x-values for the plot
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

# Calculate the probability density function (PDF)
pdf = norm.pdf(x, mu, sigma)

# Plot the PDF
plt.figure(figsize=(8, 5))
plt.plot(x, pdf, color='blue', linewidth=2)
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Normal Distribution (μ={}, σ={})'.format(mu, sigma))
plt.grid(True)
plt.show()

# %% [markdown]
# Q23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

# Parameters for the Poisson distribution
lambda_value = 4  # Average rate (mean)

# Define the range of possible values (0 to some maximum)
x_values = np.arange(0, 11)  # Values from 0 to 10

# Calculate the CDF for each value
cdf_values = poisson.cdf(x_values, mu=lambda_value)

# Display the CDF values
for x, cdf in zip(x_values, cdf_values):
    print(f"P(X <= {x}) = {cdf:.4f}")

# Plot the CDF
plt.step(x_values, cdf_values, where='post', label="CDF", color='blue')
plt.title("CDF of Poisson Distribution (λ=4)")
plt.xlabel("x (Number of Events)")
plt.ylabel("P(X ≤ x)")
plt.xticks(x_values)
plt.grid(alpha=0.3)
plt.legend()
plt.show()
# Out:
# P(X <= 0) = 0.0183
# P(X <= 1) = 0.0916
# P(X <= 2) = 0.2381
# P(X <= 3) = 0.4335
# P(X <= 4) = 0.6288
# P(X <= 5) = 0.7851
# P(X <= 6) = 0.8893
# P(X <= 7) = 0.9489
# P(X <= 8) = 0.9786
# P(X <= 9) = 0.9919
# P(X <= 10) = 0.9972

# %% [markdown]
# Q24. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# Define the interval for the uniform distribution
a = 0  # Lower bound
b = 10  # Upper bound

# Generate a single random variable from the uniform distribution
random_variable = np.random.uniform(a, b)

# Calculate the expected value of the uniform distribution
expected_value = (a + b) / 2

print(f"Simulated Random Variable: {random_variable:.2f}")
print(f"Expected Value of the Uniform Distribution: {expected_value}")
# Out:
# Simulated Random Variable: 6.78
# Expected Value of the Uniform Distribution: 5.0

# %% [markdown]
# Q25. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

def compare_standard_deviations(data1, data2):
  """
  Compares the standard deviations of two datasets.

  Args:
    data1: The first dataset.
    data2: The second dataset.

  Returns:
    A tuple containing:
      - std_dev1: Standard deviation of the first dataset.
      - std_dev2: Standard deviation of the second dataset.
  """

  std_dev1 = np.std(data1, ddof=1)  # Sample standard deviation
  std_dev2 = np.std(data2, ddof=1)  # Sample standard deviation

  return std_dev1, std_dev2

# Sample datasets
data1 = np.random.normal(loc=10, scale=2, size=100)  # Mean 10, Standard Deviation 2
data2 = np.random.normal(loc=15, scale=5, size=100)  # Mean 15, Standard Deviation 5

# Calculate standard deviations
std_dev1, std_dev2 = compare_standard_deviations(data1, data2)

# Print results
print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")

# Visualize the data (optional)
plt.figure(figsize=(8, 4))
plt.hist(data1, bins=20, alpha=0.5, label='Dataset 1')
plt.hist(data2, bins=20, alpha=0.5, label='Dataset 2')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend()
plt.title('Comparison of Datasets')
plt.show()

# Perform F-test to compare variances
f_statistic, p_value = f_oneway(data1, data2)

# Significance level
alpha = 0.05

if p_value < alpha:
    print(f"F-test: Reject the null hypothesis (variances are significantly different).")
else:
    print(f"F-test: Fail to reject the null hypothesis (variances may be equal).")
# Out:
# Standard Deviation of Dataset 1: 1.81
# Standard Deviation of Dataset 2: 5.30
# F-test: Reject the null hypothesis (variances are significantly different).

# %% [markdown]
# Q26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np

# Generate sample data from a normal distribution
mu = 0  # Mean of the distribution
sigma = 1  # Standard deviation of the distribution
sample_size = 100
data = np.random.normal(loc=mu, scale=sigma, size=sample_size)

# Calculate range
data_sorted = np.sort(data)
data_range = data_sorted[-1] - data_sorted[0]

# Calculate IQR
q1, q3 = np.percentile(data, [25, 75])  # Calculate Q1 and Q3 simultaneously
iqr = q3 - q1

print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 4.73
# Interquartile Range (IQR): 1.22

# %% [markdown]
# Q27. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data (standard normal distribution)
data = np.random.randn(1000)

# Calculate mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

# Perform Z-score normalization
z_scores = (data - mean) / std_dev

# Create histograms
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.hist(data, bins=30, density=True, alpha=0.7, label='Original Data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Original Data')

plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, density=True, alpha=0.7, label='Z-scores')
plt.xlabel('Z-score')
plt.ylabel('Density')
plt.title('Histogram of Z-scores')

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Q28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.

# %%
import numpy as np

def calculate_skewness_kurtosis(data):
  """
  Calculates the skewness and kurtosis of a given dataset.

  Args:
    data: A NumPy array containing the dataset.

  Returns:
    A tuple containing:
      - skewness: The skewness of the dataset.
      - kurtosis: The kurtosis of the dataset (Fisher's definition).
  """

  skewness = np.mean(((data - np.mean(data)) / np.std(data))**3)
  kurtosis = np.mean(((data - np.mean(data)) / np.std(data))**4) - 3

  return skewness, kurtosis

# Generate sample data from a normal distribution
mu = 0  # Mean
sigma = 1  # Standard deviation
sample_size = 1000
data = np.random.normal(loc=mu, scale=sigma, size=sample_size)

# Calculate skewness and kurtosis
skewness, kurtosis = calculate_skewness_kurtosis(data)

# Print the results
print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis: {kurtosis:.4f}")
# Out:
# Skewness: -0.0531
# Kurtosis: -0.0916
